# %%
# Importing modules
import pandas as pd
import os
os.chdir('..')
# Read data into papers
papers = pd.read_csv(r'C:\Users\67307\Documents\CSCI 5523\OLAugSep.csv')
# Print head
papers.head(1000)
# Out:
#     Unnamed: 0 Like count Retweet count               Source  \
# 0            0        0.0           0.0                IFTTT
# 1            1        0.0           0.0      IAMBLOG2TWITTER
# 2            2        1.0           1.0      Twitter Web App
# 3            3        1.0           0.0       Hootsuite Inc.
# 4            4        0.0           1.0               Buffer
# ..         ...        ...           ...                  ...
# 995         26       21.0          12.0      Twitter Web App
# 996         27        1.0           0.0  Twitter for Android
# 997         28        0.0           0.0               Tumblr
# 998         29        0.0           0.0          Zoho Social
# 999         30        0.0           0.0       Hootsuite Inc.
#
#                 User location                 date  \
# 0                         NaN  2020-09-19 22:36:15
# 1                   Worldwide  2020-09-19 21:33:19
# 2                       Dakar  2020-09-19 21:49:10
# ...

# %%
df = papers.drop(columns=['Unnamed: 0', 'Source', 'date', 'tweet_id'], axis=1)
df.head()
# Out:
#   Like count Retweet count             User location  \
# 0        0.0           0.0                       NaN
# 1        0.0           0.0                 Worldwide
# 2        1.0           1.0                     Dakar
# 3        1.0           0.0  Calgary, Alberta, Canada
# 4        0.0           1.0       Colchester, England
#
#                                                tweet
# 0  Useful Resources to Educate Students on Racism...
# 1  Reville: In This Uncertain Time, Every Student...
# 2  #onlinelearning (W38A20): #Philippines, the Da...
# 3  From business to health, #PM to #PR, our #onli...
# 4  The positive trend towards online learning dur...

# %%
df.info()
dff = df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24082 entries, 0 to 24081
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Like count     24078 non-null  object
#  1   Retweet count  24076 non-null  object
#  2   User location  18788 non-null  object
#  3   tweet          24076 non-null  object
# dtypes: object(4)
# memory usage: 752.7+ KB

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18788 entries, 1 to 24081
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Like count     18788 non-null  object
#  1   Retweet count  18788 non-null  object
#  2   User location  18788 non-null  object
#  3   tweet          18788 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
dff['tweet'].shape
# Out:
# (18788,)

# %%
dff.head()
# Out:
#   Like count Retweet count             User location  \
# 1        0.0           0.0                 Worldwide
# 2        1.0           1.0                     Dakar
# 3        1.0           0.0  Calgary, Alberta, Canada
# 4        0.0           1.0       Colchester, England
# 5        1.0           0.0                   Sevilla
#
#                                                tweet
# 1  Reville: In This Uncertain Time, Every Student...
# 2  #onlinelearning (W38A20): #Philippines, the Da...
# 3  From business to health, #PM to #PR, our #onli...
# 4  The positive trend towards online learning dur...
# 5  Infographic On Gamification In eLearning: 6 Ex...

# %%
dff.reset_index(drop=True)
# Out:
#        Like count  Retweet count                   User location  \
# 0             0.0            0.0                       Worldwide
# 1             1.0            1.0                           Dakar
# 2             1.0            0.0        Calgary, Alberta, Canada
# 3             0.0            1.0             Colchester, England
# 4             1.0            0.0                         Sevilla
# ...           ...            ...                             ...
# 18783         2.0            0.0                   Pensacola, FL
# 18784  Like count  Retweet count                   User location
# 18785         0.0            0.0                  Manjung, Perak
# 18786         0.0            0.0  451 W. Lambert Road Ste 206 Br
# 18787         1.0            0.0               Bx, Manhattan, SI
#
#                                                    tweet
# 0      Reville: In This Uncertain Time, Every Student...
# 1      #onlinelearning (W38A20): #Philippines, the Da...
# ...

# %%
import preprocessor as p
import re

# df['tweet'] = df['tweet'].map(lambda x: re.sub('[,\.!?]', '', x))

dff['tweet_clean'] = dff['tweet'].map(lambda x: p.clean(x))

dff['paper_text_processed'] = dff['tweet_clean'].map(lambda x: re.sub('[,\.!?]', '', x))
# Convert the titles to lowercase
dff['paper_text_processed'] = dff['paper_text_processed'].map(lambda x: x.lower())
# Print out the first rows of papers
dff['paper_text_processed'].head()
# Out:
# C:\Users\67307\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\67307\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\67307\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dff['paper_text_processed'][1]
# Out:
# 'reville: in this uncertain time every student needs an education navigator and a success plan to read more: *'

# %%
from nltk.tokenize import word_tokenize  
from nltk.corpus import stopwords  

stop_words = set(stopwords.words('english'))  

long_string = ','.join(list(dff['paper_text_processed'].values))
test = word_tokenize(long_string)
word_tokens = test

filtered_sentence = [w for w in word_tokens if not w in stop_words]  
  
filtered_sentence = []  
  
for w in word_tokens:  
    if w not in stop_words:  
        filtered_sentence.append(w)  

new_string = ','.join(filtered_sentence)

# %%
filtered_sentence[0]
# Out:
# 'reville'

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud 

stop_words = ["https", "co", "RT","amp",'tco','we are','online learning','onlinelearning','elearning','online']

wordcloud = WordCloud(width=800, height=400,
                      stopwords = stop_words,background_color="white",
                      max_words=5000, contour_width=5, contour_color='steelblue',
                     collocations=False)
# Generate a word cloud
wordcloud.generate(new_string)
# Visualize the word cloud
# plt.figure( figsize=(20,10) )
# plt.imshow(wordcloud)

wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x20207A09708>

# %%
new_string[150]
# Out:
# 'd'

# %%
from nltk.tokenize import word_tokenize  
from nltk.corpus import stopwords  
dff['tok_text'] = dff['paper_text_processed'].map(lambda x: word_tokenize(x))
# Out:
# C:\Users\67307\Anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
tokenized_tweet = dff['tok_text']

# %%
# stop_words = set(stopwords.words('english'))  

# long_string = ','.join(list(df['tok_text'].values))
# test = word_tokenize(long_string)
# word_tokens = test
word_tokens = ' '.join([(text) for text in df['tidy_tweet']])


filtered_sentence = [w for w in word_tokens if not w in stop_words]  
  
filtered_sentence = []  
  
for w in word_tokens:  
    if w not in stop_words:  
        filtered_sentence.append(w)

# %%
new_string = ','.join(filtered_sentence)

# %%
df['tidy_tweet']
# Out:
# 0                               i wan na have that ticket
# 1       ways to improve online course completion rates...
# 2       designed and delivered an eight-module online ...
# 3       thanks for the neche the commission commends f...
# 4                             another training session at
#                               ...
# 4793                                                tweet
# 4794    : the second of my two-part blog on communicat...
# 4795        work smarter- ted talks teachers should watch
# 4796    golden goals from this month1 read daily every...
# 4797    do n't let anything block your path to the no ...
# Name: tidy_tweet, Length: 4798, dtype: object

# %%
from afinn import Afinn
af = Afinn()
af.score('bad')
# Out:
# -3.0

# %%
sentiment_scores = [af.score(tweet) for tweet in dff['tweet']]
# sentiment_scores = [af.score(tweet) for tweet in filtered_sentence]


sentiment_category = ['positive' if score > 0 
                          else 'negative' if score < 0 
                              else 'neutral' 
                                  for score in sentiment_scores]

# %%
plt.hist(sentiment_scores)
# Out:
# (array([1.2000e+01, 1.1700e+02, 1.3910e+03, 1.3426e+04, 3.1930e+03,
#         5.9700e+02, 4.2000e+01, 8.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([-13. ,  -8.8,  -4.6,  -0.4,   3.8,   8. ,  12.2,  16.4,  20.6,
#          24.8,  29. ]),
#  <a list of 10 Patch objects>)

# %%
sentiment_category
# Out:
# ['positive',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
#  'negative',
#  'positive',
#  'neutral',
#  'positive',
#  'neutral',
#  'neutral',
#  'neutral',
#  'positive',
#  'positive',
#  'neutral',
#  'positive',
# ...

# %%
df1 = pd.DataFrame([sentiment_scores, sentiment_category]).T
df1.columns = [ 'sentiment_score', 'sentiment_category']
df1['sentiment_score'] = df1.sentiment_score.astype('float')
# df1.groupby(by=['news_category']).describe()

# %%
import seaborn as sns
sns.countplot(x='sentiment_category',data=df1)

# %%
import collections
ctr = collections.Counter(sentiment_category)
print("Frequency of the elements in the List : ",ctr)
# Out:
# Frequency of the elements in the List :  Counter({'positive': 10151, 'neutral': 7117, 'negative': 1520})

# %%
df_final = df.dropna()

# %%
df_final['tidy_tweet'].describe()
# Out:
# count     55838
# unique    30072
# top
# freq       1920
# Name: tidy_tweet, dtype: object
